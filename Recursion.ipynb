# %% [markdown]
# <a href="https://colab.research.google.com/github/Rachitha18348/Python/blob/main/Recursion.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#factorial
def Fact(n):
  if n==1:
    return 1
  else:
    return n*Fact(n-1)
n=int(input())
print(Fact(n))
# Out:
# 5
# 120

# %%
def Fact(n): #Fiboniac sum
    if n==1:
        return 1
    else:
      return n*Fact(n-1)


print(Fact(5))
# Out:
# 120

# %%
def Fab(n):
  a=0;b=1
  for i in range(n):
    print(a)
    a,b=b,a+b
Fab(5)
# Out:
# 0
# 1
# 1
# 2
# 3

# %%
def Fib(n):
    a=0;b=1;s=0
    for i in range(n):
        s+=a
        a,b=b,a+b
    return s

print(Fib(6))
# Out:
# 12

# %%
#Fiboniac series in recursion
def Fib(n):
  if n==0:
    return 0
  elif n==1:
    return 1
  else:
    return Fib(n-1)+Fib(n-2)
for i in range(6):
  print(Fib(i))
# Out:
# 0
# 1
# 1
# 2
# 3
# 5

# %%
#Fiboniac series sum in recursion
def Fib(n):
  if n==0:
    return 0
  elif n==1:
    return 1
  else:
    return Fib(n-1)+Fib(n-2)
n=int(input("Enter number:"))
print(Fib(n))
# Out:
# Enter number:5
# 5
